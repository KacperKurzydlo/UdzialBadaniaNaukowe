# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperKurzydlo/UdzialBadaniaNaukowe/blob/main/Sie%C4%87_v6_Dziura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import laplace
from scipy.integrate import solve_bvp

import tensorflow
from tensorflow.keras import layers, models
from tensorflow.keras import Input, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Reshape
import datetime

# %%
from numba import njit

@njit
def laplace_2d_converge(u, nx, ny, hs, maxiter, tol=1e-6):
    """
    Solves the 2D Laplace equation using the Jacobi method with convergence checking,
    and applies boundary conditions with a fixed zero potential at the center of the domain.
    """
    for iteration in range(maxiter):
        u_old = u.copy()

        # Vectorized update for interior points
        u[1:-1, 1:-1] = 0.25 * (
            u_old[2:, 1:-1] +  # u[i+1, j]
            u_old[:-2, 1:-1] +  # u[i-1, j]
            u_old[1:-1, 2:] +  # u[i, j+1]
            u_old[1:-1, :-2]   # u[i, j-1]
        )

        center_x, center_y = nx // 2, ny // 2
        half_size = hs

        u[center_y - half_size:center_y + half_size + 1, center_x - half_size:center_x + half_size + 1] = 0.0

        # Check for convergence
        max_change = np.max(np.abs(u - u_old))
        if max_change < tol:
            break

    return u

# Define the domain and boundary conditions
nx, ny = 100, 100
x, y = np.meshgrid(np.linspace(0, 1, nx), np.linspace(0, 1, ny))
dx, dy = 1 / (nx - 1), 1 / (ny - 1)

N = 1000

train_set = np.zeros([N, nx, ny])
labels_train = np.zeros([N, 5])

for i in range(N):

    # Initial guess
    u = np.zeros((ny, nx))

    t = np.random.uniform(0, 1)
    b = np.random.uniform(0, 1)
    l = np.random.uniform(0, 1)
    r = np.random.uniform(0, 1)

    hole_size = np.random.uniform(0, 20) # Size of the hole in the middle x2

    # Boundary conditions (Dirichlet)
    u[0, :] = t  # Top boundary
    u[-1, :] = b  # Bottom boundary
    u[:, 0] = l  # Left boundary
    u[:, -1] = r  # Right boundary

    labels_train[i][0] = t
    labels_train[i][1] = b
    labels_train[i][2] = l
    labels_train[i][3] = r
    labels_train[i][4] = hole_size

    # Solve the Laplace equation
    u = laplace_2d_converge(u, nx, ny, hole_size, maxiter=100000, tol=1e-6)

    train_set[i] = u
    if i % 100 == 0:
        print(f"Iteration {i}/{N}")
# Out:
# Iteration 0/1000
# Iteration 100/1000
# Iteration 200/1000
# Iteration 300/1000
# Iteration 400/1000
# Iteration 500/1000
# Iteration 600/1000
# Iteration 700/1000
# Iteration 800/1000
# Iteration 900/1000

# %%
plt.pcolormesh(train_set[0], cmap="hot")

# %%
u_train_reshaped = train_set[:N-100]
u_test_reshaped = train_set[N-100:]

labels_train_reshaped  = labels_train[:N-100].reshape(-1, 5)
labels_test_reshaped  = labels_train[N-100:].reshape(-1, 5)

# %%
initializer1 = tensorflow.keras.initializers.HeNormal()
initializer2 = tensorflow.keras.initializers.GlorotUniform()

# %%
input_shape = (5,)
network = Sequential()

network.add(Dense(64, activation='relu', input_shape=input_shape))
network.add(Dense(128, activation='relu'))
network.add(Dense(256, activation='relu'))
network.add(Dense(512, activation='relu'))
#network.add(Dense(512, activation='tanh'))

network.add(Dense(nx * ny, activation='linear'))
network.add(Reshape((nx, ny)))

network.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10000)               │       5,130,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 100, 100)            │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,303,312 (20.23 MB)
#  Trainable params: 5,303,312 (20.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.optimizers import Adam

opt = Adam()
network.compile(optimizer='Adam', loss='mse', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.keras', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit(labels_train_reshaped,
                      u_train_reshaped,
                      validation_data = (labels_test_reshaped, u_test_reshaped),
                      steps_per_epoch = 50,
                      validation_steps = 50,
                      epochs=100,
                      callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.1047 - loss: 0.0858
# Epoch 1: val_accuracy improved from -inf to 0.23520, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 0.1058 - loss: 0.0852 - val_accuracy: 0.2352 - val_loss: 0.0218 - learning_rate: 0.0010
# Epoch 2/100
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
#  1/50 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.1578 - loss: 0.0226
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_accuracy available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.2740 - loss: 0.0198
# Epoch 3: val_accuracy improved from 0.23520 to 0.44980, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 95ms/step - accuracy: 0.2748 - loss: 0.0197 - val_accuracy: 0.4498 - val_loss: 0.0069 - learning_rate: 0.0010
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 394us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.5172 - loss: 0.0054
# Epoch 5: val_accuracy improved from 0.44980 to 0.69640, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.5186 - loss: 0.0054 - val_accuracy: 0.6964 - val_loss: 8.9872e-04 - learning_rate: 0.0010
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.7413 - loss: 8.2955e-04
# Epoch 7: val_accuracy improved from 0.69640 to 0.72580, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - accuracy: 0.7415 - loss: 8.2798e-04 - val_accuracy: 0.7258 - val_loss: 6.7677e-04 - learning_rate: 0.0010
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7611 - loss: 6.7706e-04
# Epoch 9: val_accuracy improved from 0.72580 to 0.73470, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.7611 - loss: 6.7950e-04 - val_accuracy: 0.7347 - val_loss: 6.0071e-04 - learning_rate: 0.0010
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7428 - loss: 7.7896e-04
# Epoch 11: val_accuracy improved from 0.73470 to 0.75500, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.7432 - loss: 7.7672e-04 - val_accuracy: 0.7550 - val_loss: 4.2544e-04 - learning_rate: 0.0010
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.7790 - loss: 4.5268e-04
# Epoch 13: val_accuracy improved from 0.75500 to 0.75880, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.7790 - loss: 4.5226e-04 - val_accuracy: 0.7588 - val_loss: 3.5745e-04 - learning_rate: 0.0010
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7748 - loss: 3.5210e-04
# Epoch 15: val_accuracy improved from 0.75880 to 0.76520, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 111ms/step - accuracy: 0.7750 - loss: 3.5215e-04 - val_accuracy: 0.7652 - val_loss: 4.4873e-04 - learning_rate: 0.0010
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7874 - loss: 3.1613e-04
# Epoch 17: val_accuracy improved from 0.76520 to 0.76730, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - accuracy: 0.7873 - loss: 3.1665e-04 - val_accuracy: 0.7673 - val_loss: 5.2406e-04 - learning_rate: 0.0010
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.8192 - loss: 5.6947e-05 - val_accuracy: 0.8007 - val_loss: 8.0298e-05 - learning_rate: 2.5000e-04
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 433us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8260 - loss: 7.4301e-05
# Epoch 95: val_accuracy did not improve from 0.80350
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.8260 - loss: 7.4142e-05 - val_accuracy: 0.8018 - val_loss: 7.9785e-05 - learning_rate: 2.5000e-04
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 375us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8182 - loss: 5.5548e-05
# Epoch 97: val_accuracy improved from 0.80350 to 0.80400, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 103ms/step - accuracy: 0.8183 - loss: 5.5659e-05 - val_accuracy: 0.8040 - val_loss: 8.2694e-05 - learning_rate: 2.5000e-04
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8072 - loss: 5.6700e-05
# Epoch 99: val_accuracy did not improve from 0.80400
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.8074 - loss: 5.6732e-05 - val_accuracy: 0.7982 - val_loss: 9.1876e-05 - learning_rate: 2.5000e-04
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 396us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.keras')

# %%
pred_image = network.predict(np.array([0.1, 0.2, 0.3, 0.4]).reshape(1, 4))[0]
plt.pcolormesh(pred_image, cmap='hot')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %%
from sklearn.metrics import mean_squared_error

for its in range(10):

  # Test the prediction for a random boundary condition
  boundary_conditions = np.array([np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 20)]).reshape(1, 5)

  pred_image = network.predict(boundary_conditions)[0]

  u = np.zeros((ny, nx))  # Initial guess

  t, b, l, r, hole_size = boundary_conditions[0]

  # Apply boundary conditions (Dirichlet)
  u[0, :] = t  # Top boundary
  u[-1, :] = b  # Bottom boundary
  u[:, 0] = l  # Left boundary
  u[:, -1] = r  # Right boundary

  # Solve the Laplace equation using the Jacobi method
  laplace_solution = laplace_2d_converge(u, nx, ny, hole_size, maxiter=100000, tol=1e-6)

  # Calculate the Mean Squared Error (MSE) between the two solutions
  mse = mean_squared_error(laplace_solution.flatten(), pred_image.flatten())
  print(f"Mean Squared Error between Laplace solution and neural network prediction: {mse:.4e}")

  # Visualize both solutions to compare
  fig, ax = plt.subplots(1, 3, figsize=(20, 6))

  # Plot the Laplace solution
  c0 = ax[0].pcolormesh(laplace_solution, cmap='hot')
  ax[0].set_title('Laplace Solution')
  ax[0].set_xlabel('X')
  ax[0].set_ylabel('Y')
  fig.colorbar(c0, ax=ax[0], orientation='vertical')

  # Plot the neural network prediction
  c1 = ax[1].pcolormesh(pred_image, cmap='hot')
  ax[1].set_title('Neural Network Prediction')
  ax[1].set_xlabel('X')
  ax[1].set_ylabel('Y')
  fig.colorbar(c1, ax=ax[1], orientation='vertical')

  # Optionally, plot the absolute difference between the two solutions
  c2 = ax[2].pcolormesh(np.abs(laplace_solution - pred_image), cmap='viridis')
  ax[2].set_title('Absolute Difference')
  ax[2].set_xlabel('X')
  ax[2].set_ylabel('Y')
  fig.colorbar(c2, ax=ax[2], orientation='vertical')

  plt.tight_layout()
  plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 9.9554e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 3.6968e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 8.8303e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 9.7737e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 4.6883e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 2.5373e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 8.5415e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.1216e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.6935e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 4.7355e-05
