# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperKurzydlo/UdzialBadaniaNaukowe/blob/main/Sie%C4%87_v9_Ko%C5%82o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import laplace
from scipy.integrate import solve_bvp

import tensorflow
from tensorflow.keras import layers, models
from tensorflow.keras import Input, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Reshape
from tensorflow.keras.optimizers import Adam
import datetime

# %%
from numba import njit

@njit
def laplace_2d_converge(u, nx, ny, radius, maxiter, tol=1e-6):
    """
    Solves the 2D Laplace equation using the Jacobi method with convergence checking,
    and applies boundary conditions with a fixed zero potential in the center of the domain (circular hole).
    """
    center_x, center_y = nx // 2, ny // 2

    for iteration in range(maxiter):
        u_old = u.copy()

        # Vectorized update for interior points
        u[1:-1, 1:-1] = 0.25 * (
            u_old[2:, 1:-1] +  # u[i+1, j]
            u_old[:-2, 1:-1] +  # u[i-1, j]
            u_old[1:-1, 2:] +  # u[i, j+1]
            u_old[1:-1, :-2]   # u[i, j-1]
        )

        # Apply the circular hole boundary condition
        for i in range(ny):
            for j in range(nx):
                if (i - center_y)**2 + (j - center_x)**2 <= radius**2:
                    u[i, j] = 0.0

        # Check for convergence
        max_change = np.max(np.abs(u - u_old))
        if max_change < tol:
            break

    return u

# Define the domain and boundary conditions
nx, ny = 100, 100
x, y = np.meshgrid(np.linspace(0, 1, nx), np.linspace(0, 1, ny))
dx, dy = 1 / (nx - 1), 1 / (ny - 1)

N = 1000

train_set = np.zeros([N, nx, ny])
labels_train = np.zeros([N, 5])

for i in range(N):

    # Initial guess
    u = np.zeros((ny, nx))

    t = np.random.uniform(0, 1)
    b = np.random.uniform(0, 1)
    l = np.random.uniform(0, 1)
    r = np.random.uniform(0, 1)

    hole_radius = int(np.random.uniform(15, 20))  # Radius of the circular hole

    # Boundary conditions (Dirichlet)
    u[0, :] = t  # Top boundary
    u[-1, :] = b  # Bottom boundary
    u[:, 0] = l  # Left boundary
    u[:, -1] = r  # Right boundary

    labels_train[i][0] = t
    labels_train[i][1] = b
    labels_train[i][2] = l
    labels_train[i][3] = r
    labels_train[i][4] = hole_radius

    # Solve the Laplace equation
    u = laplace_2d_converge(u, nx, ny, hole_radius, maxiter=100000, tol=1e-6)

    train_set[i] = u
    if i % 100 == 0:
        print(f"Iteration {i}/{N}")
# Out:
# Iteration 0/1000
# Iteration 100/1000
# Iteration 200/1000
# Iteration 300/1000
# Iteration 400/1000
# Iteration 500/1000
# Iteration 600/1000
# Iteration 700/1000
# Iteration 800/1000
# Iteration 900/1000

# %%
u_train_reshaped = train_set[:N-100]
u_test_reshaped = train_set[N-100:]

labels_train_reshaped  = labels_train[:N-100].reshape(-1, 5)
labels_test_reshaped  = labels_train[N-100:].reshape(-1, 5)

# %%
labels_train_reshaped = tensorflow.convert_to_tensor(labels_train_reshaped, dtype=tensorflow.float32)
u_train_reshaped = tensorflow.convert_to_tensor(u_train_reshaped, dtype=tensorflow.float32)

labels_test_reshaped = tensorflow.convert_to_tensor(labels_test_reshaped, dtype=tensorflow.float32)
u_test_reshaped = tensorflow.convert_to_tensor(u_test_reshaped, dtype=tensorflow.float32)

# %%
initializer1 = tensorflow.keras.initializers.HeNormal()
initializer2 = tensorflow.keras.initializers.GlorotUniform()

# %%
input_shape = (5,)
network = Sequential()

network.add(Dense(64, activation='relu', input_shape=input_shape))
network.add(Dense(128, activation='relu'))

network.add(Dense(256, activation='relu'))
network.add(Dense(512, activation='relu'))

network.add(Dense(nx * ny, activation='linear'))
network.add(Reshape((nx, ny)))

network.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10000)               │       5,130,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 100, 100)            │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,303,312 (20.23 MB)
#  Trainable params: 5,303,312 (20.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

opt = Adam()
network.compile(optimizer='Adam', loss='mse', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.keras', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit(labels_train_reshaped,
                      u_train_reshaped,
                      validation_data = (labels_test_reshaped, u_test_reshaped),
                      steps_per_epoch = 50,
                      validation_steps = 50,
                      epochs=100,
                      callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1283 - loss: 0.0606
# Epoch 1: val_accuracy improved from -inf to 0.27180, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.1302 - loss: 0.0602 - val_accuracy: 0.2718 - val_loss: 0.0311 - learning_rate: 0.0010
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/100
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_accuracy available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3301 - loss: 0.0270
# Epoch 3: val_accuracy improved from 0.27180 to 0.46410, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.3309 - loss: 0.0270 - val_accuracy: 0.4641 - val_loss: 0.0199 - learning_rate: 0.0010
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4840 - loss: 0.0172
# Epoch 5: val_accuracy improved from 0.46410 to 0.50800, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 97ms/step - accuracy: 0.4846 - loss: 0.0171 - val_accuracy: 0.5080 - val_loss: 0.0115 - learning_rate: 0.0010
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5989 - loss: 0.0084
# Epoch 7: val_accuracy improved from 0.50800 to 0.60730, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.5997 - loss: 0.0084 - val_accuracy: 0.6073 - val_loss: 0.0070 - learning_rate: 0.0010
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7043 - loss: 0.0046
# Epoch 9: val_accuracy improved from 0.60730 to 0.82650, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.7053 - loss: 0.0046 - val_accuracy: 0.8265 - val_loss: 3.1620e-04 - learning_rate: 0.0010
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8481 - loss: 2.9984e-04
# Epoch 11: val_accuracy improved from 0.82650 to 0.86040, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8481 - loss: 2.9953e-04 - val_accuracy: 0.8604 - val_loss: 1.7648e-04 - learning_rate: 0.0010
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8699 - loss: 1.7978e-04
# Epoch 13: val_accuracy improved from 0.86040 to 0.86170, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.8699 - loss: 1.7996e-04 - val_accuracy: 0.8617 - val_loss: 1.7190e-04 - learning_rate: 0.0010
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8734 - loss: 2.0846e-04
# Epoch 15: val_accuracy improved from 0.86170 to 0.86570, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 88ms/step - accuracy: 0.8734 - loss: 2.0806e-04 - val_accuracy: 0.8657 - val_loss: 1.5624e-04 - learning_rate: 0.0010
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8808 - loss: 1.7737e-04
# Epoch 17: val_accuracy did not improve from 0.86570
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.8808 - loss: 1.7738e-04 - val_accuracy: 0.8599 - val_loss: 1.5390e-04 - learning_rate: 0.0010
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8766 - loss: 1.6532e-04
# Epoch 19: val_accuracy did not improve from 0.86570
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.8765 - loss: 1.6544e-04 - val_accuracy: 0.8546 - val_loss: 1.6451e-04 - learning_rate: 0.0010
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8828 - loss: 1.6986e-04
# Epoch 21: val_accuracy did not improve from 0.86570
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.8826 - loss: 1.6987e-04 - val_accuracy: 0.8493 - val_loss: 1.6418e-04 - learning_rate: 0.0010
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8765 - loss: 1.6931e-04
# Epoch 23: val_accuracy did not improve from 0.86570
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.8765 - loss: 1.6943e-04 - val_accuracy: 0.8624 - val_loss: 1.4862e-04 - learning_rate: 0.0010
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8649 - loss: 1.5406e-04
# Epoch 25: val_accuracy did not improve from 0.86570
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.8651 - loss: 1.5412e-04 - val_accuracy: 0.8616 - val_loss: 1.2601e-04 - learning_rate: 0.0010
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 342us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8793 - loss: 1.3723e-04
# Epoch 27: val_accuracy improved from 0.86570 to 0.86810, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 7s 108ms/step - accuracy: 0.8794 - loss: 1.3714e-04 - val_accuracy: 0.8681 - val_loss: 1.2204e-04 - learning_rate: 5.0000e-04
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8815 - loss: 1.2361e-04
# Epoch 29: val_accuracy improved from 0.86810 to 0.86980, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - accuracy: 0.8816 - loss: 1.2365e-04 - val_accuracy: 0.8698 - val_loss: 1.3141e-04 - learning_rate: 5.0000e-04
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8862 - loss: 1.2876e-04
# Epoch 31: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.8861 - loss: 1.2871e-04 - val_accuracy: 0.8656 - val_loss: 1.1878e-04 - learning_rate: 5.0000e-04
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8834 - loss: 1.2628e-04
# Epoch 33: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.8834 - loss: 1.2622e-04 - val_accuracy: 0.8594 - val_loss: 1.2333e-04 - learning_rate: 5.0000e-04
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8846 - loss: 1.2536e-04
# Epoch 35: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.8845 - loss: 1.2529e-04 - val_accuracy: 0.8678 - val_loss: 1.0805e-04 - learning_rate: 5.0000e-04
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8802 - loss: 1.1484e-04
# Epoch 37: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.8802 - loss: 1.1492e-04 - val_accuracy: 0.8652 - val_loss: 1.1542e-04 - learning_rate: 5.0000e-04
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8855 - loss: 1.2558e-04
# Epoch 39: val_accuracy did not improve from 0.86980
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.8854 - loss: 1.2557e-04 - val_accuracy: 0.8618 - val_loss: 1.6123e-04 - learning_rate: 5.0000e-04
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8861 - loss: 1.1637e-04
# Epoch 41: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - accuracy: 0.8860 - loss: 1.1639e-04 - val_accuracy: 0.8646 - val_loss: 9.9661e-05 - learning_rate: 2.5000e-04
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8841 - loss: 1.0502e-04
# Epoch 43: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.8841 - loss: 1.0505e-04 - val_accuracy: 0.8663 - val_loss: 1.0154e-04 - learning_rate: 2.5000e-04
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 405us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8901 - loss: 1.0399e-04
# Epoch 45: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.8900 - loss: 1.0406e-04 - val_accuracy: 0.8671 - val_loss: 1.0546e-04 - learning_rate: 2.5000e-04
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8813 - loss: 1.0352e-04
# Epoch 47: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 99ms/step - accuracy: 0.8813 - loss: 1.0355e-04 - val_accuracy: 0.8599 - val_loss: 9.8906e-05 - learning_rate: 2.5000e-04
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8803 - loss: 1.0454e-04
# Epoch 49: val_accuracy did not improve from 0.86980
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.8804 - loss: 1.0458e-04 - val_accuracy: 0.8670 - val_loss: 9.7923e-05 - learning_rate: 2.5000e-04
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8993 - loss: 1.0333e-04
# Epoch 51: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.8990 - loss: 1.0325e-04 - val_accuracy: 0.8684 - val_loss: 9.6264e-05 - learning_rate: 1.2500e-04
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 406us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8871 - loss: 9.8372e-05
# Epoch 53: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 97ms/step - accuracy: 0.8870 - loss: 9.8379e-05 - val_accuracy: 0.8671 - val_loss: 9.4927e-05 - learning_rate: 1.2500e-04
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 352us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8890 - loss: 1.0378e-04
# Epoch 55: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.8889 - loss: 1.0367e-04 - val_accuracy: 0.8667 - val_loss: 9.6274e-05 - learning_rate: 1.2500e-04
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8692 - loss: 9.4700e-05
# Epoch 57: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - accuracy: 0.8695 - loss: 9.4760e-05 - val_accuracy: 0.8678 - val_loss: 9.1742e-05 - learning_rate: 1.2500e-04
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8881 - loss: 1.0105e-04
# Epoch 59: val_accuracy did not improve from 0.86980
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.8880 - loss: 1.0096e-04 - val_accuracy: 0.8676 - val_loss: 9.2800e-05 - learning_rate: 1.2500e-04
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8747 - loss: 9.2459e-05
# Epoch 61: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step - accuracy: 0.8749 - loss: 9.2501e-05 - val_accuracy: 0.8654 - val_loss: 9.2062e-05 - learning_rate: 6.2500e-05
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 400us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8799 - loss: 9.8313e-05
# Epoch 63: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - accuracy: 0.8800 - loss: 9.8231e-05 - val_accuracy: 0.8669 - val_loss: 9.0268e-05 - learning_rate: 6.2500e-05
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8886 - loss: 9.5069e-05
# Epoch 65: val_accuracy did not improve from 0.86980
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.8885 - loss: 9.5022e-05 - val_accuracy: 0.8661 - val_loss: 9.0614e-05 - learning_rate: 6.2500e-05
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8834 - loss: 9.3491e-05
# Epoch 67: val_accuracy improved from 0.86980 to 0.86990, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.8834 - loss: 9.3519e-05 - val_accuracy: 0.8699 - val_loss: 9.1930e-05 - learning_rate: 6.2500e-05
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8935 - loss: 9.3365e-05
# Epoch 69: val_accuracy did not improve from 0.86990
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - accuracy: 0.8933 - loss: 9.3359e-05 - val_accuracy: 0.8656 - val_loss: 8.9581e-05 - learning_rate: 6.2500e-05
# Epoch 69: early stopping

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.keras')

# %%
# pred_image = network.predict(np.array([0.1, 0.2, 0.3, 0.4]).reshape(1, 4))[0]
# plt.pcolormesh(pred_image, cmap='hot')

# %%
from sklearn.metrics import mean_squared_error

for its in range(10):

  # Test the prediction for a random boundary condition
  boundary_conditions = np.array([np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  int(np.random.uniform(15, 20))]).reshape(1, 5)

  pred_image = network.predict(boundary_conditions)[0]

  u = np.zeros((ny, nx))  # Initial guess

  t, b, l, r, hole_size = boundary_conditions[0]

  # Apply boundary conditions (Dirichlet)
  u[0, :] = t  # Top boundary
  u[-1, :] = b  # Bottom boundary
  u[:, 0] = l  # Left boundary
  u[:, -1] = r  # Right boundary

  # Solve the Laplace equation using the Jacobi method
  laplace_solution = laplace_2d_converge(u, nx, ny, hole_size, maxiter=100000, tol=1e-6)

  # Calculate the Mean Squared Error (MSE) between the two solutions
  mse = mean_squared_error(laplace_solution.flatten(), pred_image.flatten())
  print(f"Mean Squared Error between Laplace solution and neural network prediction: {mse:.4e}")

  # Visualize both solutions to compare
  fig, ax = plt.subplots(1, 3, figsize=(20, 6))

  # Plot the Laplace solution
  c0 = ax[0].pcolormesh(laplace_solution, cmap='hot')
  ax[0].set_title('Laplace Solution')
  ax[0].set_xlabel('X')
  ax[0].set_ylabel('Y')
  fig.colorbar(c0, ax=ax[0], orientation='vertical')

  # Plot the neural network prediction
  c1 = ax[1].pcolormesh(pred_image, cmap='hot')
  ax[1].set_title('Neural Network Prediction')
  ax[1].set_xlabel('X')
  ax[1].set_ylabel('Y')
  fig.colorbar(c1, ax=ax[1], orientation='vertical')

  # Optionally, plot the absolute difference between the two solutions
  c2 = ax[2].pcolormesh(np.abs(laplace_solution - pred_image), cmap='viridis')
  ax[2].set_title('Absolute Difference')
  ax[2].set_xlabel('X')
  ax[2].set_ylabel('Y')
  fig.colorbar(c2, ax=ax[2], orientation='vertical')

  plt.tight_layout()
  plt.show()

  # Additional plots: Projections along X and Y axes
  fig, axs = plt.subplots(1, 2, figsize=(16, 6))

  # Extract and plot projections along the x-axis (y=0)
  x_values = np.arange(nx)
  u_pred_x_proj = pred_image[ny // 2, :]  # Middle row corresponds to y = 0
  u_expected_x_proj = laplace_solution[ny // 2, :]  # Expected values along y = 0
  residual_x = np.abs(u_pred_x_proj - u_expected_x_proj)

  axs[0].plot(x_values, u_pred_x_proj, label="Predicted", linestyle="--")
  axs[0].plot(x_values, u_expected_x_proj, label="Expected", linestyle="-")
  axs[0].fill_between(x_values, residual_x, color="red", alpha=0.3, label="Absolute Difference")
  axs[0].set_title("Projection along x-axis (y=0)")
  axs[0].set_xlabel("x")
  axs[0].set_ylabel("u(x, 0)")
  axs[0].legend()

  # Extract and plot projections along the y-axis (x=0)
  y_values = np.arange(ny)
  u_pred_y_proj = pred_image[:, nx // 2]  # Middle column corresponds to x = 0
  u_expected_y_proj = laplace_solution[:, nx // 2]  # Expected values along x = 0
  residual_y = np.abs(u_pred_y_proj - u_expected_y_proj)

  axs[1].plot(y_values, u_pred_y_proj, label="Predicted", linestyle="--")
  axs[1].plot(y_values, u_expected_y_proj, label="Expected", linestyle="-")
  axs[1].fill_between(y_values, residual_y, color="red", alpha=0.3, label="Residual")
  axs[1].set_title("Projection along y-axis (x=0)")
  axs[1].set_xlabel("y")
  axs[1].set_ylabel("u(0, y)")
  axs[1].legend()

  plt.suptitle("Comparison of Expected and Predicted Solutions with Projections")
  plt.tight_layout()
  plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 8.7164e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.4816e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.0935e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.4504e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 5.5287e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.6849e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 7.6040e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 8.6821e-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.3102e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 7.3182e-05
