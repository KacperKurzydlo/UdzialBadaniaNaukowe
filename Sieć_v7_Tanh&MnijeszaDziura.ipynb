# %% [markdown]
# <a href="https://colab.research.google.com/github/KacperKurzydlo/UdzialBadaniaNaukowe/blob/main/Sie%C4%87_v7_Tanh%26MnijeszaDziura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import laplace
from scipy.integrate import solve_bvp

import tensorflow
from tensorflow.keras import layers, models
from tensorflow.keras import Input, Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, BatchNormalization, Dropout
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Reshape
import datetime

# %%
from numba import njit

@njit
def laplace_2d_converge(u, nx, ny, hs, maxiter, tol=1e-6):
    """
    Solves the 2D Laplace equation using the Jacobi method with convergence checking,
    and applies boundary conditions with a fixed zero potential at the center of the domain.
    """
    for iteration in range(maxiter):
        u_old = u.copy()

        # Vectorized update for interior points
        u[1:-1, 1:-1] = 0.25 * (
            u_old[2:, 1:-1] +  # u[i+1, j]
            u_old[:-2, 1:-1] +  # u[i-1, j]
            u_old[1:-1, 2:] +  # u[i, j+1]
            u_old[1:-1, :-2]   # u[i, j-1]
        )

        center_x, center_y = nx // 2, ny // 2
        half_size = hs

        u[center_y - half_size:center_y + half_size + 1, center_x - half_size:center_x + half_size + 1] = 0.0

        # Check for convergence
        max_change = np.max(np.abs(u - u_old))
        if max_change < tol:
            break

    return u

# Define the domain and boundary conditions
nx, ny = 100, 100
x, y = np.meshgrid(np.linspace(0, 1, nx), np.linspace(0, 1, ny))
dx, dy = 1 / (nx - 1), 1 / (ny - 1)

N = 1000

train_set = np.zeros([N, nx, ny])
labels_train = np.zeros([N, 5])

for i in range(N):

    # Initial guess
    u = np.zeros((ny, nx))

    t = np.random.uniform(0, 1)
    b = np.random.uniform(0, 1)
    l = np.random.uniform(0, 1)
    r = np.random.uniform(0, 1)

    hole_size = int(np.random.uniform(10, 20)) # Size of the hole in the middle x2

    # Boundary conditions (Dirichlet)
    u[0, :] = t  # Top boundary
    u[-1, :] = b  # Bottom boundary
    u[:, 0] = l  # Left boundary
    u[:, -1] = r  # Right boundary

    labels_train[i][0] = t
    labels_train[i][1] = b
    labels_train[i][2] = l
    labels_train[i][3] = r
    labels_train[i][4] = hole_size

    # Solve the Laplace equation
    u = laplace_2d_converge(u, nx, ny, hole_size, maxiter=100000, tol=1e-6)

    train_set[i] = u
    if i % 100 == 0:
        print(f"Iteration {i}/{N}")
# Out:
# Iteration 0/1000
# Iteration 100/1000
# Iteration 200/1000
# Iteration 300/1000
# Iteration 400/1000
# Iteration 500/1000
# Iteration 600/1000
# Iteration 700/1000
# Iteration 800/1000
# Iteration 900/1000

# %%
u_train_reshaped = train_set[:N-100]
u_test_reshaped = train_set[N-100:]

labels_train_reshaped  = labels_train[:N-100].reshape(-1, 5)
labels_test_reshaped  = labels_train[N-100:].reshape(-1, 5)

# %%
initializer1 = tensorflow.keras.initializers.HeNormal()
initializer2 = tensorflow.keras.initializers.GlorotUniform()

# %%
input_shape = (5,)
network = Sequential()

network.add(Dense(64, activation='relu', input_shape=input_shape))
network.add(Dense(128, activation='relu'))

network.add(Dense(256, activation='relu'))
network.add(Dense(512, activation='relu'))

network.add(Dense(128, activation='tanh'))
network.add(Dense(256, activation='tanh'))


network.add(Dense(nx * ny, activation='linear'))
network.add(Reshape((nx, ny)))

network.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_28 (Dense)                     │ (None, 64)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 512)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 256)                 │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 10000)               │       2,570,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_4 (Reshape)                  │ (None, 100, 100)            │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,842,000 (10.84 MB)
#  Trainable params: 2,842,000 (10.84 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
from tensorflow.keras.optimizers import Adam

opt = Adam()
network.compile(optimizer='Adam', loss='mse', metrics = ['accuracy'])

# %%
es = EarlyStopping(monitor = 'val_accuracy', min_delta = 0.001, patience = 20, verbose =1)
model_cp = ModelCheckpoint(filepath = 'best_model1.keras', monitor = 'val_accuracy', save_best_only = True, verbose = 1)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 5, verbose=1, factor=0.5, min_lr=0.00001)

# %%
history = network.fit(labels_train_reshaped,
                      u_train_reshaped,
                      validation_data = (labels_test_reshaped, u_test_reshaped),
                      steps_per_epoch = 50,
                      validation_steps = 50,
                      epochs=100,
                      callbacks=[es, model_cp, learning_rate_reduction])
# Out:
# Epoch 1/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0921 - loss: 0.0707
# Epoch 1: val_accuracy improved from -inf to 0.24070, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.0942 - loss: 0.0698 - val_accuracy: 0.2407 - val_loss: 0.0352 - learning_rate: 0.0010
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/early_stopping.py:155: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/model_checkpoint.py:206: UserWarning: Can save best model only with val_accuracy available, skipping.
#   self._save_model(epoch=epoch, batch=None, logs=logs)
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks/callback_list.py:96: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2467 - loss: 0.0342
# Epoch 3: val_accuracy did not improve from 0.24070
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.2472 - loss: 0.0342 - val_accuracy: 0.2227 - val_loss: 0.0312 - learning_rate: 0.0010
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.2604 - loss: 0.0284
# Epoch 5: val_accuracy improved from 0.24070 to 0.32480, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.2615 - loss: 0.0284 - val_accuracy: 0.3248 - val_loss: 0.0157 - learning_rate: 0.0010
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3949 - loss: 0.0151
# Epoch 7: val_accuracy improved from 0.32480 to 0.59180, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.3962 - loss: 0.0151 - val_accuracy: 0.5918 - val_loss: 0.0071 - learning_rate: 0.0010
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6929 - loss: 0.0049
# Epoch 9: val_accuracy improved from 0.59180 to 0.74840, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6936 - loss: 0.0049 - val_accuracy: 0.7484 - val_loss: 0.0012 - learning_rate: 0.0010
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 11/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8289 - loss: 6.7479e-04
# Epoch 11: val_accuracy improved from 0.74840 to 0.82990, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.8288 - loss: 6.6815e-04 - val_accuracy: 0.8299 - val_loss: 2.7297e-04 - learning_rate: 0.0010
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 13/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8424 - loss: 2.5890e-04
# Epoch 13: val_accuracy improved from 0.82990 to 0.83090, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8424 - loss: 2.5871e-04 - val_accuracy: 0.8309 - val_loss: 2.9981e-04 - learning_rate: 0.0010
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8529 - loss: 2.5858e-04
# Epoch 15: val_accuracy did not improve from 0.83090
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8529 - loss: 2.5811e-04 - val_accuracy: 0.8176 - val_loss: 2.2694e-04 - learning_rate: 0.0010
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8425 - loss: 2.4534e-04
# Epoch 17: val_accuracy did not improve from 0.83090
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8426 - loss: 2.4577e-04 - val_accuracy: 0.7949 - val_loss: 3.4788e-04 - learning_rate: 0.0010
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 365us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 19/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8279 - loss: 3.0747e-04
# Epoch 19: val_accuracy did not improve from 0.83090
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8284 - loss: 3.0820e-04 - val_accuracy: 0.8089 - val_loss: 3.2225e-04 - learning_rate: 0.0010
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 21/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8472 - loss: 2.6033e-04
# Epoch 21: val_accuracy did not improve from 0.83090
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8473 - loss: 2.5889e-04 - val_accuracy: 0.8193 - val_loss: 2.7148e-04 - learning_rate: 0.0010
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 0.0010
# Epoch 23/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8686 - loss: 2.0355e-04
# Epoch 23: val_accuracy did not improve from 0.83090
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8684 - loss: 2.0293e-04 - val_accuracy: 0.8284 - val_loss: 2.0775e-04 - learning_rate: 0.0010
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 25/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8628 - loss: 1.4772e-04
# Epoch 25: val_accuracy improved from 0.83090 to 0.84770, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.8630 - loss: 1.4740e-04 - val_accuracy: 0.8477 - val_loss: 1.3084e-04 - learning_rate: 5.0000e-04
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 27/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8570 - loss: 1.3606e-04
# Epoch 27: val_accuracy did not improve from 0.84770
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8574 - loss: 1.3584e-04 - val_accuracy: 0.8451 - val_loss: 1.5427e-04 - learning_rate: 5.0000e-04
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 29/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8558 - loss: 1.3569e-04
# Epoch 29: val_accuracy did not improve from 0.84770
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8562 - loss: 1.3559e-04 - val_accuracy: 0.8448 - val_loss: 1.3257e-04 - learning_rate: 5.0000e-04
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8691 - loss: 1.2395e-04
# Epoch 31: val_accuracy did not improve from 0.84770
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8691 - loss: 1.2397e-04 - val_accuracy: 0.8476 - val_loss: 1.2623e-04 - learning_rate: 5.0000e-04
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 33/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8739 - loss: 1.2185e-04
# Epoch 33: val_accuracy improved from 0.84770 to 0.85500, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.8737 - loss: 1.2212e-04 - val_accuracy: 0.8550 - val_loss: 1.2308e-04 - learning_rate: 5.0000e-04
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8582 - loss: 1.2188e-04
# Epoch 35: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - accuracy: 0.8585 - loss: 1.2191e-04 - val_accuracy: 0.8295 - val_loss: 1.2857e-04 - learning_rate: 5.0000e-04
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8568 - loss: 1.2932e-04
# Epoch 37: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8569 - loss: 1.2934e-04 - val_accuracy: 0.8492 - val_loss: 1.1713e-04 - learning_rate: 5.0000e-04
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 39/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8835 - loss: 1.1987e-04
# Epoch 39: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8829 - loss: 1.2006e-04 - val_accuracy: 0.8534 - val_loss: 1.1276e-04 - learning_rate: 5.0000e-04
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 41/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8779 - loss: 1.2251e-04
# Epoch 41: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8775 - loss: 1.2258e-04 - val_accuracy: 0.8522 - val_loss: 1.0710e-04 - learning_rate: 5.0000e-04
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 5.0000e-04
# Epoch 43/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8692 - loss: 1.1392e-04
# Epoch 43: val_accuracy did not improve from 0.85500
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8692 - loss: 1.1412e-04 - val_accuracy: 0.8446 - val_loss: 1.2209e-04 - learning_rate: 5.0000e-04
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8730 - loss: 1.0666e-04
# Epoch 45: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8730 - loss: 1.0666e-04 - val_accuracy: 0.8532 - val_loss: 1.0264e-04 - learning_rate: 2.5000e-04
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8614 - loss: 1.0985e-04
# Epoch 47: val_accuracy did not improve from 0.85500
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8616 - loss: 1.0975e-04 - val_accuracy: 0.8534 - val_loss: 9.8598e-05 - learning_rate: 2.5000e-04
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8747 - loss: 9.7164e-05
# Epoch 49: val_accuracy improved from 0.85500 to 0.85530, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8747 - loss: 9.7263e-05 - val_accuracy: 0.8553 - val_loss: 1.0980e-04 - learning_rate: 2.5000e-04
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 354us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 51/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8760 - loss: 1.1348e-04
# Epoch 51: val_accuracy did not improve from 0.85530
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8758 - loss: 1.1328e-04 - val_accuracy: 0.8539 - val_loss: 9.9652e-05 - learning_rate: 2.5000e-04
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8607 - loss: 1.1081e-04
# Epoch 53: val_accuracy did not improve from 0.85530
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8609 - loss: 1.1069e-04 - val_accuracy: 0.8508 - val_loss: 1.0290e-04 - learning_rate: 2.5000e-04
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8723 - loss: 1.0120e-04
# Epoch 55: val_accuracy did not improve from 0.85530
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.8723 - loss: 1.0124e-04 - val_accuracy: 0.8546 - val_loss: 1.0248e-04 - learning_rate: 2.5000e-04
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8667 - loss: 1.0306e-04
# Epoch 57: val_accuracy improved from 0.85530 to 0.85680, saving model to best_model1.keras
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8668 - loss: 1.0299e-04 - val_accuracy: 0.8568 - val_loss: 1.0234e-04 - learning_rate: 2.5000e-04
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8743 - loss: 9.9833e-05
# Epoch 59: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8743 - loss: 9.9872e-05 - val_accuracy: 0.8559 - val_loss: 9.7417e-05 - learning_rate: 2.5000e-04
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 403us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8685 - loss: 9.8342e-05
# Epoch 61: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8686 - loss: 9.8353e-05 - val_accuracy: 0.8504 - val_loss: 9.4349e-05 - learning_rate: 2.5000e-04
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 63/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8803 - loss: 9.6607e-05
# Epoch 63: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8799 - loss: 9.6606e-05 - val_accuracy: 0.8450 - val_loss: 9.6545e-05 - learning_rate: 2.5000e-04
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 361us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8763 - loss: 9.1681e-05
# Epoch 65: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8763 - loss: 9.1782e-05 - val_accuracy: 0.8477 - val_loss: 9.7699e-05 - learning_rate: 2.5000e-04
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 2.5000e-04
# Epoch 67/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8665 - loss: 9.6923e-05
# Epoch 67: val_accuracy did not improve from 0.85680
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 42ms/step - accuracy: 0.8666 - loss: 9.6931e-05 - val_accuracy: 0.8471 - val_loss: 1.0002e-04 - learning_rate: 2.5000e-04
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 69/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8747 - loss: 1.0224e-04
# Epoch 69: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8747 - loss: 1.0180e-04 - val_accuracy: 0.8552 - val_loss: 8.6307e-05 - learning_rate: 1.2500e-04
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8777 - loss: 8.7594e-05
# Epoch 71: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8777 - loss: 8.7583e-05 - val_accuracy: 0.8538 - val_loss: 9.0724e-05 - learning_rate: 1.2500e-04
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8655 - loss: 8.9038e-05
# Epoch 73: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.8657 - loss: 8.9014e-05 - val_accuracy: 0.8528 - val_loss: 8.7095e-05 - learning_rate: 1.2500e-04
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 75/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8809 - loss: 8.5630e-05
# Epoch 75: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.8807 - loss: 8.5644e-05 - val_accuracy: 0.8532 - val_loss: 8.4722e-05 - learning_rate: 1.2500e-04
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 1.2500e-04
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8656 - loss: 8.7519e-05
# Epoch 77: val_accuracy did not improve from 0.85680
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.8657 - loss: 8.7552e-05 - val_accuracy: 0.8530 - val_loss: 8.4135e-05 - learning_rate: 1.2500e-04
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 388us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 79/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.8715 - loss: 7.8203e-05
# Epoch 79: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8716 - loss: 7.8408e-05 - val_accuracy: 0.8465 - val_loss: 8.5174e-05 - learning_rate: 6.2500e-05
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8741 - loss: 8.5743e-05
# Epoch 81: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8742 - loss: 8.5687e-05 - val_accuracy: 0.8530 - val_loss: 8.1619e-05 - learning_rate: 6.2500e-05
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8776 - loss: 8.1213e-05
# Epoch 83: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8775 - loss: 8.1237e-05 - val_accuracy: 0.8533 - val_loss: 8.1381e-05 - learning_rate: 6.2500e-05
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 85/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8760 - loss: 8.1800e-05
# Epoch 85: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.8760 - loss: 8.1835e-05 - val_accuracy: 0.8539 - val_loss: 8.1700e-05 - learning_rate: 6.2500e-05
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 6.2500e-05
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8649 - loss: 8.3707e-05
# Epoch 87: val_accuracy did not improve from 0.85680
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8651 - loss: 8.3692e-05 - val_accuracy: 0.8520 - val_loss: 8.1196e-05 - learning_rate: 6.2500e-05
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8712 - loss: 8.0500e-05
# Epoch 89: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8713 - loss: 8.0515e-05 - val_accuracy: 0.8530 - val_loss: 7.8825e-05 - learning_rate: 3.1250e-05
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 91/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8826 - loss: 8.0915e-05
# Epoch 91: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8823 - loss: 8.0897e-05 - val_accuracy: 0.8520 - val_loss: 7.8816e-05 - learning_rate: 3.1250e-05
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8912 - loss: 8.1861e-05
# Epoch 93: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.8909 - loss: 8.1826e-05 - val_accuracy: 0.8531 - val_loss: 7.8934e-05 - learning_rate: 3.1250e-05
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8877 - loss: 7.8691e-05
# Epoch 95: val_accuracy did not improve from 0.85680
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.8875 - loss: 7.8713e-05 - val_accuracy: 0.8532 - val_loss: 7.9318e-05 - learning_rate: 3.1250e-05
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 423us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - learning_rate: 3.1250e-05
# Epoch 97/100
# 49/50 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8735 - loss: 7.7529e-05
# Epoch 97: val_accuracy did not improve from 0.85680
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8736 - loss: 7.7626e-05 - val_accuracy: 0.8520 - val_loss: 7.8704e-05 - learning_rate: 3.1250e-05
# Epoch 97: early stopping

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model('/content/best_model1.keras')

# %%
# pred_image = network.predict(np.array([0.1, 0.2, 0.3, 0.4]).reshape(1, 4))[0]
# plt.pcolormesh(pred_image, cmap='hot')

# %%
from sklearn.metrics import mean_squared_error

for its in range(10):

  # Test the prediction for a random boundary condition
  boundary_conditions = np.array([np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  np.random.uniform(0, 1),
                                  int(np.random.uniform(10, 20))]).reshape(1, 5)

  pred_image = network.predict(boundary_conditions)[0]

  u = np.zeros((ny, nx))  # Initial guess

  t, b, l, r, hole_size = boundary_conditions[0]

  # Apply boundary conditions (Dirichlet)
  u[0, :] = t  # Top boundary
  u[-1, :] = b  # Bottom boundary
  u[:, 0] = l  # Left boundary
  u[:, -1] = r  # Right boundary

  # Solve the Laplace equation using the Jacobi method
  laplace_solution = laplace_2d_converge(u, nx, ny, hole_size, maxiter=100000, tol=1e-6)

  # Calculate the Mean Squared Error (MSE) between the two solutions
  mse = mean_squared_error(laplace_solution.flatten(), pred_image.flatten())
  print(f"Mean Squared Error between Laplace solution and neural network prediction: {mse:.4e}")

  # Visualize both solutions to compare
  fig, ax = plt.subplots(1, 3, figsize=(20, 6))

  # Plot the Laplace solution
  c0 = ax[0].pcolormesh(laplace_solution, cmap='hot')
  ax[0].set_title('Laplace Solution')
  ax[0].set_xlabel('X')
  ax[0].set_ylabel('Y')
  fig.colorbar(c0, ax=ax[0], orientation='vertical')

  # Plot the neural network prediction
  c1 = ax[1].pcolormesh(pred_image, cmap='hot')
  ax[1].set_title('Neural Network Prediction')
  ax[1].set_xlabel('X')
  ax[1].set_ylabel('Y')
  fig.colorbar(c1, ax=ax[1], orientation='vertical')

  # Optionally, plot the absolute difference between the two solutions
  c2 = ax[2].pcolormesh(np.abs(laplace_solution - pred_image), cmap='viridis')
  ax[2].set_title('Absolute Difference')
  ax[2].set_xlabel('X')
  ax[2].set_ylabel('Y')
  fig.colorbar(c2, ax=ax[2], orientation='vertical')

  plt.tight_layout()
  plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 2.7695e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 5.7771e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 1.5788e-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 6.3762e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 7.1046e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 3.0111e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 2.5887e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 2.5866e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 4.3006e-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Mean Squared Error between Laplace solution and neural network prediction: 2.9023e-05
